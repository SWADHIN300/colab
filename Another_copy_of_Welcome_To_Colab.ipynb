# %% [markdown]
# <a href="https://colab.research.google.com/github/SWADHIN300/colab/blob/main/Another_copy_of_Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
  'Name': [' Alice','Bob','Charlie','David','Eve'],
  'Age': [25, 30, 35,40,28],
  'City': ['New York', 'London', 'Paris','Tokyo','London'],
  'Salary': [50000, 60000,55000,65000,62000],
}
df = pd.DataFrame(data)
print("Original DaataFrame: ")
print(df)
print("df.info()")
print(df.info())
# Out:
# Original DaataFrame:
#       Name  Age      City  Salary
# 0    Alice   25  New York   50000
# 1      Bob   30    London   60000
# 2  Charlie   35     Paris   55000
# 3    David   40     Tokyo   65000
# 4      Eve   28    London   62000
# df.info()
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     5 non-null      int64
#  2   City    5 non-null      object
#  3   Salary  5 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 292.0+ bytes
# None

# %%
print(df.describe())
# Out:
#             Age        Salary
# count   5.00000      5.000000
# mean   31.60000  58400.000000
# std     5.94138   5941.380311
# min    25.00000  50000.000000
# 25%    28.00000  55000.000000
# 50%    30.00000  60000.000000
# 75%    35.00000  62000.000000
# max    40.00000  65000.000000

# %%
print(df.head(2))
# Out:
#      Name  Age      City  Salary
# 0   Alice   25  New York   50000
# 1     Bob   30    London   60000

# %%
print(df.tail(3))
# Out:
#       Name  Age    City  Salary
# 2  Charlie   35   Paris   55000
# 3    David   40   Tokyo   65000
# 4      Eve   28  London   62000

# %%
print("shape of df:",df.shape)
# Out:
# shape of df: (5, 4)

# %%
print(df['Name'])
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# 4        Eve
# Name: Name, dtype: object

# %%
print(df[['Name','City']])
# Out:
#       Name      City
# 0    Alice  New York
# 1      Bob    London
# 2  Charlie     Paris
# 3    David     Tokyo
# 4      Eve    London

# %%
print(df.iloc[1])
# Out:
# Name         Bob
# Age           30
# City      London
# Salary     60000
# Name: 1, dtype: object

# %%
print(df.loc[2,'City'])
# Out:
# Paris

# %%
print(df.iloc[0:3,0:2])
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
print(df.iloc[1:4,1:3])
# Out:
#    Age    City
# 1   30  London
# 2   35   Paris
# 3   40   Tokyo

# %%
print(df.loc[df['Age']>30])
# Out:
#       Name  Age   City  Salary
# 2  Charlie   35  Paris   55000
# 3    David   40  Tokyo   65000

# %%
print(df.loc[df['Age']>30,'Name'])
# Out:
# 2    Charlie
# 3      David
# Name: Name, dtype: object

# %%
print(df.loc[df['City']=='London','Name'])
# Out:
# 1    Bob
# 4    Eve
# Name: Name, dtype: object

# %%
df['Couuntry']=['USA','UK','France','Japan','UK']
print("Added 'Country' colum:")
print(df)
# Out:
# Added 'Country' colum:
#       Name  Age      City  Salary Couuntry
# 0    Alice   25  New York   50000      USA
# 1      Bob   30    London   60000       UK
# 2  Charlie   35     Paris   55000   France
# 3    David   40     Tokyo   65000    Japan
# 4      Eve   28    London   62000       UK

# %%
df.loc[len(df)] = ['Frank',32,'Paris',60000,'France']
print(df)
# Out:
#       Name  Age      City  Salary Couuntry
# 0    Alice   25  New York   50000      USA
# 1      Bob   30    London   60000       UK
# 2  Charlie   35     Paris   55000   France
# 3    David   40     Tokyo   65000    Japan
# 4      Eve   28    London   62000       UK
# 5    Frank   32     Paris   60000   France
# 6    Frank   32     Paris   60000   France
# 7    Frank   32     Paris   60000   France

# %%
print("sort by age (descending):")
print(df.sort_values('Age',ascending=False))
# Out:
# sort by age (descending):
#       Name  Age      City  Salary Couuntry
# 3    David   40     Tokyo   65000    Japan
# 2  Charlie   35     Paris   55000   France
# 5    Frank   32     Paris   60000   France
# 1      Bob   30    London   60000       UK
# 4      Eve   28    London   62000       UK
# 0    Alice   25  New York   50000      USA

# %%
print("hey Swadhin")
# Out:
# hey Swadhin
